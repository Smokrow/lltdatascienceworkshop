# %%
# %pip install ax-platform matplotlib
# Out:
# Collecting ax-platform
#   Downloading ax_platform-1.3.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.8.0)
# Collecting botorch<0.18.2dev9999,>=0.18.1 (from botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Downloading botorch-0.18.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from ax-platform) (3.1.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from ax-platform) (2.1.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.11/site-packages (from ax-platform) (1.11.3)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.11/site-packages (from ax-platform) (1.3.1)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.11/site-packages (from ax-platform) (8.1.5)
# Requirement already satisfied: plotly>=5.12.0 in /opt/conda/lib/python3.11/site-packages (from ax-platform) (5.24.1)
# Collecting pyre-extensions (from ax-platform)
#   Using cached pyre_extensions-0.0.32-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from ax-platform) (1.14.0)
# Collecting markdown (from ax-platform)
#   Using cached markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting graphviz (from ax-platform)
#   Using cached graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.11/site-packages (from botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (4.16.0)
# Collecting gpytorch>=1.15.2 (from botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Using cached gpytorch-1.15.2-py3-none-any.whl.metadata (8.2 kB)
# Collecting linear_operator>=0.6.1 (from botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Using cached linear_operator-0.6.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=2.4 in /opt/conda/lib/python3.11/site-packages (from botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (2.13.0)
# Collecting multipledispatch (from botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Using cached multipledispatch-1.0.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: threadpoolctl in /opt/conda/lib/python3.11/site-packages (from botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (3.2.0)
# Collecting ninja (from botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting pymoo (from botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Downloading pymoo-0.6.2-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from plotly>=5.12.0->ax-platform) (9.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.11/site-packages (from ipywidgets->ax-platform) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.11/site-packages (from ipywidgets->ax-platform) (8.16.1)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.11/site-packages (from ipywidgets->ax-platform) (5.11.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/conda/lib/python3.11/site-packages (from ipywidgets->ax-platform) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/conda/lib/python3.11/site-packages (from ipywidgets->ax-platform) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->ax-platform) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->ax-platform) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas->ax-platform) (2023.3)
# Collecting typing-inspect (from pyre-extensions->ax-platform)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from scikit-learn->ax-platform) (1.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy->ax-platform) (1.3.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (2.16.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->ax-platform) (4.8.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (3.29.7)
# Requirement already satisfied: setuptools>=77.0.3 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (83.0.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (3.2)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (2023.9.2)
# Requirement already satisfied: cuda-toolkit==13.0.3 in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (13.0.3.0)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (3.4.5)
# Requirement already satisfied: triton==3.7.1 in /opt/conda/lib/python3.11/site-packages (from torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (3.7.1)
# Requirement already satisfied: nvidia-cublas==13.1.1.3.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (13.1.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (13.0.88)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (12.0.0.61)
# Requirement already satisfied: nvidia-nvjitlink<14,>=13.0.88 in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (13.3.33)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (12.6.3.3)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.3; platform_system == "Linux"->torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (13.0.85)
# Collecting moocore>=0.1.7 (from pymoo->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Downloading moocore-0.3.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Collecting autograd>=1.4 (from pymoo->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Downloading autograd-1.9.1-py3-none-any.whl.metadata (6.1 kB)
# Collecting cma>=3.4.0 (from pymoo->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Using cached cma-4.4.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting alive_progress (from pymoo->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Using cached alive_progress-3.3.0-py3-none-any.whl.metadata (72 kB)
# Collecting Deprecated (from pymoo->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Using cached deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect->pyre-extensions->ax-platform)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /opt/conda/lib/python3.11/site-packages (from cuda-bindings<14,>=13.0.3->torch>=2.4->botorch<0.18.2dev9999,>=0.18.1->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (1.5.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ax-platform) (0.8.3)
# Collecting cffi>=1.17.1 (from moocore>=0.1.7->pymoo->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Downloading cffi-2.1.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.5 kB)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.11/site-packages (from moocore>=0.1.7->pymoo->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (3.11.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->ax-platform) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->ax-platform) (0.2.8)
# Collecting about-time==4.2.1 (from alive_progress->pymoo->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Using cached about_time-4.2.1-py3-none-any.whl.metadata (13 kB)
# Collecting graphemeu==0.7.2 (from alive_progress->pymoo->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Using cached graphemeu-0.7.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting wrapt<3,>=1.10 (from Deprecated->pymoo->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform)
#   Downloading wrapt-2.2.2-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ax-platform) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ax-platform) (2.4.0)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ax-platform) (0.2.2)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.17.1->moocore>=0.1.7->pymoo->botorch[pymoo]<0.18.2dev9999,>=0.18.1->ax-platform) (2.21)
# Downloading ax_platform-1.3.1-py3-none-any.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 56.6 MB/s eta 0:00:0000:0100:01
# Downloading botorch-0.18.1-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 41.2 MB/s eta 0:00:0000:0100:01
# Using cached graphviz-0.21-py3-none-any.whl (47 kB)
# Using cached markdown-3.10.2-py3-none-any.whl (108 kB)
# Using cached pyre_extensions-0.0.32-py3-none-any.whl (12 kB)
# Using cached gpytorch-1.15.2-py3-none-any.whl (291 kB)
# Using cached linear_operator-0.6.1-py3-none-any.whl (174 kB)
# Using cached multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 18.6 MB/s eta 0:00:00
# Downloading pymoo-0.6.2-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 69.7 MB/s eta 0:00:0000:01:00:01
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading autograd-1.9.1-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 6.4 MB/s eta 0:00:00
# Using cached cma-4.4.4-py3-none-any.whl (328 kB)
# Downloading moocore-0.3.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (866 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 866.9/866.9 kB 59.4 MB/s eta 0:00:00
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached alive_progress-3.3.0-py3-none-any.whl (78 kB)
# Using cached about_time-4.2.1-py3-none-any.whl (13 kB)
# Using cached graphemeu-0.7.2-py3-none-any.whl (22 kB)
# Using cached deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading cffi-2.1.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (217 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.9/217.9 kB 20.3 MB/s eta 0:00:00
# Downloading wrapt-2.2.2-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.7/159.7 kB 20.0 MB/s eta 0:00:00
# Installing collected packages: multipledispatch, wrapt, ninja, mypy-extensions, markdown, graphviz, graphemeu, cma, cffi, autograd, about-time, typing-inspect, moocore, Deprecated, alive_progress, pyre-extensions, pymoo, linear_operator, gpytorch, botorch, ax-platform
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.16.0
#     Uninstalling cffi-1.16.0:
#       Successfully uninstalled cffi-1.16.0
# Successfully installed Deprecated-1.3.1 about-time-4.2.1 alive_progress-3.3.0 autograd-1.9.1 ax-platform-1.3.1 botorch-0.18.1 cffi-2.1.0 cma-4.4.4 gpytorch-1.15.2 graphemeu-0.7.2 graphviz-0.21 linear_operator-0.6.1 markdown-3.10.2 moocore-0.3.1 multipledispatch-1.0.0 mypy-extensions-1.1.0 ninja-1.13.0 pymoo-0.6.2 pyre-extensions-0.0.32 typing-inspect-0.9.0 wrapt-2.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from ax.api.client import Client
from ax.api.configs import RangeParameterConfig
from botorch.models import SingleTaskGP
from botorch.fit import fit_gpytorch_mll
from gpytorch.mlls import ExactMarginalLogLikelihood


def objective(x): return -(x - 1.5) ** 2 + 4

client = Client()
client.configure_experiment(parameters=[
    RangeParameterConfig(name="x", parameter_type="float", bounds=(-3, 5))
])
client.configure_optimization(objective="score")


xs, ys = [], []
for _ in range(15):
    for trial_id, parameters in client.get_next_trials(max_trials=1).items():
        x, y = parameters["x"], objective(parameters["x"])
        xs.append(x)
        ys.append(y)
        client.complete_trial(trial_index=trial_id, raw_data={"score": y})

train_x = torch.tensor(xs).unsqueeze(-1)
train_y = torch.tensor(ys).unsqueeze(-1)

gp = SingleTaskGP(train_x, train_y)
fit_gpytorch_mll(ExactMarginalLogLikelihood(gp.likelihood, gp))

grid = torch.linspace(-3, 5, 300).unsqueeze(-1)
with torch.no_grad():
    posterior = gp.posterior(grid)
    mean = posterior.mean.squeeze()
    lower, upper = posterior.mvn.confidence_region()

x_plot = grid.squeeze().numpy()
plt.plot(x_plot, objective(x_plot), label="True function")
plt.plot(x_plot, mean.numpy(), "--", label="GP posterior mean")
plt.fill_between(x_plot, lower.numpy(), upper.numpy(), alpha=.25,
                 label="95% confidence interval")
plt.scatter(xs, ys, label="Ax evaluations", zorder=3)
best = np.argmax(ys)
plt.scatter(xs[best], ys[best], marker="*", s=180, label="Best found", zorder=4)
plt.xlabel("x"); plt.ylabel("score"); plt.legend(); plt.tight_layout(); plt.show()
# Out:
# [INFO 07-12 06:57:17] ax.api.client: GenerationStrategy(name='Center+Sobol+MBM:fast', nodes=[CenterGenerationNode(next_node_name='Sobol', use_existing_trials_for_initialization=True), GenerationNode(name='Sobol', generator_specs=[GeneratorSpec(generator_enum=Sobol, generator_key_override=None)], transition_criteria=[MinTrials(transition_to='MBM'), MinTrials(transition_to='MBM')], suggested_experiment_status=ExperimentStatus.INITIALIZATION, pausing_criteria=[MaxTrialsAwaitingData(threshold=5)]), GenerationNode(name='MBM', generator_specs=[GeneratorSpec(generator_enum=BoTorch, generator_key_override=None)], transition_criteria=None, suggested_experiment_status=ExperimentStatus.OPTIMIZATION, pausing_criteria=None)]) chosen based on user input and problem structure.
# [INFO 07-12 06:57:17] ax.api.client: Generated new trial 0 with parameters {'x': 1.0} using GenerationNode CenterOfSearchSpace.
# [INFO 07-12 06:57:17] ax.api.client: Trial 0 marked COMPLETED.
# [INFO 07-12 06:57:17] ax.api.client: Generated new trial 1 with parameters {'x': 2.53338} using GenerationNode Sobol.
# [INFO 07-12 06:57:17] ax.api.client: Trial 1 marked COMPLETED.
# [INFO 07-12 06:57:17] ax.api.client: Generated new trial 2 with parameters {'x': 0.78004} using GenerationNode Sobol.
# [INFO 07-12 06:57:17] ax.api.client: Trial 2 marked COMPLETED.
# [INFO 07-12 06:57:17] ax.api.client: Generated new trial 3 with parameters {'x': -1.810531} using GenerationNode Sobol.
# [INFO 07-12 06:57:17] ax.api.client: Trial 3 marked COMPLETED.
# [INFO 07-12 06:57:17] ax.api.client: Generated new trial 4 with parameters {'x': 4.498934} using GenerationNode Sobol.
# [INFO 07-12 06:57:17] ax.api.client: Trial 4 marked COMPLETED.
# [INFO 07-12 06:57:18] ax.api.client: Generated new trial 5 with parameters {'x': 1.580778} using GenerationNode MBM.
# [INFO 07-12 06:57:18] ax.api.client: Trial 5 marked COMPLETED.
# [INFO 07-12 06:57:19] ax.api.client: Generated new trial 6 with parameters {'x': 1.438696} using GenerationNode MBM.
# [INFO 07-12 06:57:19] ax.api.client: Trial 6 marked COMPLETED.
# [INFO 07-12 06:57:20] ax.api.client: Generated new trial 7 with parameters {'x': 1.685874} using GenerationNode MBM.
# [INFO 07-12 06:57:20] ax.api.client: Trial 7 marked COMPLETED.
# [INFO 07-12 06:57:21] ax.api.client: Generated new trial 8 with parameters {'x': 1.333352} using GenerationNode MBM.
# [INFO 07-12 06:57:21] ax.api.client: Trial 8 marked COMPLETED.
# [INFO 07-12 06:57:22] ax.api.client: Generated new trial 9 with parameters {'x': 1.499529} using GenerationNode MBM.
# [INFO 07-12 06:57:22] ax.api.client: Trial 9 marked COMPLETED.
# [INFO 07-12 06:57:23] ax.api.client: Generated new trial 10 with parameters {'x': 1.471819} using GenerationNode MBM.
# [INFO 07-12 06:57:23] ax.api.client: Trial 10 marked COMPLETED.
# /opt/conda/lib/python3.11/site-packages/linear_operator/utils/cholesky.py:41: NumericalWarning:
#
# A not p.d., added jitter of 1.0e-08 to the diagonal
#
# [INFO 07-12 06:57:24] ax.api.client: Generated new trial 11 with parameters {'x': -3.0} using GenerationNode MBM.
# [INFO 07-12 06:57:24] ax.api.client: Trial 11 marked COMPLETED.
# /opt/conda/lib/python3.11/site-packages/linear_operator/utils/cholesky.py:41: NumericalWarning:
#
# A not p.d., added jitter of 1.0e-08 to the diagonal
#
# [INFO 07-12 06:57:25] ax.api.client: Generated new trial 12 with parameters {'x': 1.543626} using GenerationNode MBM.
# [INFO 07-12 06:57:25] ax.api.client: Trial 12 marked COMPLETED.
# /opt/conda/lib/python3.11/site-packages/linear_operator/utils/cholesky.py:41: NumericalWarning:
#
# A not p.d., added jitter of 1.0e-08 to the diagonal
#
# /opt/conda/lib/python3.11/site-packages/botorch/optim/optimize.py:844: RuntimeWarning:
#
# Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL_TERMINATION_IN_LNSRCH.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL_TERMINATION_IN_LNSRCH.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL_TERMINATION_IN_LNSRCH.'), NumericalWarning('A not p.d., added jitter of 1.0e-08 to the diagonal')]
# Trying again with a new set of initial conditions.
#
# /opt/conda/lib/python3.11/site-packages/botorch/optim/optimize.py:844: RuntimeWarning:
#
# Optimization failed on the second try, after generating a new set of initial conditions.
#
# /opt/conda/lib/python3.11/site-packages/linear_operator/utils/cholesky.py:41: NumericalWarning:
#
# A not p.d., added jitter of 1.0e-08 to the diagonal
#
# [INFO 07-12 06:57:29] ax.api.client: Generated new trial 13 with parameters {'x': 1.516514} using GenerationNode MBM.
# [INFO 07-12 06:57:29] ax.api.client: Trial 13 marked COMPLETED.
# /opt/conda/lib/python3.11/site-packages/linear_operator/utils/cholesky.py:41: NumericalWarning:
#
# A not p.d., added jitter of 1.0e-08 to the diagonal
#
# /opt/conda/lib/python3.11/site-packages/botorch/optim/optimize.py:844: RuntimeWarning:
#
# Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL_TERMINATION_IN_LNSRCH.')]
# Trying again with a new set of initial conditions.
#
# /opt/conda/lib/python3.11/site-packages/botorch/optim/optimize.py:844: RuntimeWarning:
#
# Optimization failed on the second try, after generating a new set of initial conditions.
#
# [INFO 07-12 06:57:32] ax.api.client: Generated new trial 14 with parameters {'x': 1.486498} using GenerationNode MBM.
# [INFO 07-12 06:57:32] ax.api.client: Trial 14 marked COMPLETED.
# /opt/conda/lib/python3.11/site-packages/botorch/models/utils/assorted.py:276: InputDataWarning:
#
# Data (input features) is not contained to the unit cube. Please consider min-max scaling the input data.
