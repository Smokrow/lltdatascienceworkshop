# %%
import numpy as np
import pyvista as pv
from pyvista import examples

# Download a volumetric dataset
vol = examples.download_knee_full()

# %%
# A nice camera position
cpos = pv.CameraPosition(
    position=(-381.74, -46.02, 216.54),
    focal_point=(74.8305, 89.2905, 100.0),
    viewup=(0.23, 0.072, 0.97),
)

vol.plot(volume=True, cmap='bone', cpos=cpos,jupyter_backend='trame')
# Out:
# Widget(value="<iframe src='/user/momo/proxy/36495/index.html?ui=P_0x7f82b21b0880_3&reconnect=auto' style='widt…

# %%
pyvista.Report(gpu=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pyvista.Report(gpu=False)
#
# NameError: name 'pyvista' is not defined
